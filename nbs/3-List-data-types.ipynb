# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)
print(response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# True
# [{'avg_duration': 2405.9222222222224,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 90,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2519.8811881188117,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 101,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2372.2323232323233,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 99,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2522.181818181818,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 88,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2468.8933333333334,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 75,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2665.3333333333335,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 87,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2690.7294117647057,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 85,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2483.370786516854,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 89,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2768.043956043956,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 91,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2354.6,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 100,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2472.9951923076924,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 208,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2448.257575757576,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 198,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2402.3405172413795,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 232,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2631.814655172414,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 232,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2524.7938144329896,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 194,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2545.1464435146445,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 239,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2597.8874458874457,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 231,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2494.0095693779904,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 209,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2576.7603686635944,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 217,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2535.2453703703704,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 216,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2606.305389221557,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 167,
#   'operating_system': 'MacOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2587.271676300578,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 173,
#   'operating_system': 'MacOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2674.0193548387097,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 155,
#   'operating_system': 'MacOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2462.6298342541436,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 181,
#   'operating_system': 'MacOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2498.5851063829787,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 188,
#   'operating_system': 'MacOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2476.222222222222,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 162,
#   'operating_system': 'MacOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2366.539393939394,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 165,
#   'operating_system': 'MacOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2699.9573170731705,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 164,
#   'operating_system': 'MacOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2471.863354037267,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 161,
#   'operating_system': 'MacOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2480.343373493976,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 166,
#   'operating_system': 'MacOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2824.8245614035086,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 57,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2343.48,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2765.8979591836733,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 49,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2293.0178571428573,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 56,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2643.1,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 40,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2763.4655172413795,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 58,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2476.5,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 48,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2135.7291666666665,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 48,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2384.4444444444443,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 36,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2364.2954545454545,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 44,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2544.442528735632,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 348,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2549.8,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 345,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2446.6164772727275,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 352,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2517.9742857142855,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 350,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2457.801120448179,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 357,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2473.32,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 350,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2592.146496815287,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 314,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2626.072022160665,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 361,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2592.4625,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 320,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2477.7707736389684,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 349,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2449.8275862068967,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 116,
#   'operating_system': 'iOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2637.102564102564,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 117,
#   'operating_system': 'iOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2583.6567164179105,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 134,
#   'operating_system': 'iOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2462.717391304348,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 138,
#   'operating_system': 'iOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2381.322033898305,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 118,
#   'operating_system': 'iOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2621.5704697986575,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 149,
#   'operating_system': 'iOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2667.7762237762236,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 143,
#   'operating_system': 'iOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2542.378787878788,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 132,
#   'operating_system': 'iOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2646.0615384615385,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 130,
#   'operating_system': 'iOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2462.8125,
#   'bucket': '2025-07-23T00:00:00Z',
#   'count': 128,
#   'operating_system': 'iOS',
#   'page': '/signup',
#   'ua': ''}]

# %%
detail_path = "/api/events/9/"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print(r.status_code)
if r.ok:
    data = r.json()
    pprint(data)
# Out:
# 404
